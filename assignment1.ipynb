# %% [markdown]
# <a href="https://colab.research.google.com/github/archanaad2007-cloud/ict_assignments/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter price of item1:"))
b = int(input("Enter quantity of item1:"))
r = int(input("Enter price of item2:"))
s = int(input("Enter quantity of item2:"))
amt = a*b
tma = r*s
sum = amt+tma
print("Total bill amount:",sum)
# Out:
# Enter price of item1:45
# Enter quantity of item1:3
# Enter price of item2:30
# Enter quantity of item2:2
# Total bill amount: 195

# %%
celsius = int(input("Enter temperature in celsius:"))
fahrenhiet = (c*9/5)+32
print("Temperature in fahreniet:",fahrenhiet)
# Out:
# Enter temperature in celsius:30
# Temperature in fahreniet: 86.0

# %%
b = int(input("Enter basic salary:"))
HRA = 0.20
DA = 0.10
total_salary = b + HRA + DA
print("Net salary:",total_salary)
# Out:
# Enter basic salary:20000
# Net salary: 20000.3

# %%
p = int(input("Enter principle amount:"))
r = int(input("Enter rate of interest:"))
t = int(input("Enter time:"))
SI = p*r*t/100
print("simple interest:", SI)
# Out:
# Enter principle amount:10000
# Enter rate of interest:5
# Enter time:2
# simple interest: 1000.0

# %%
t = int(input("Enter time in seconds:"))
h = t//3600
m = (t%3600)//60
s = (t%3600)%60
print("Time in hours:",h)
print("Time in minutes:",m)
print("Time in seconds:",s)
# Out:
# Enter time in seconds:130
# Time in hours: 0
# Time in minutes: 2
# Time in seconds: 10

# %%
weight = int(input("Enter weight in kg:"))
height = float(input("Enter height in meters:"))
BMI = weight/(height)**2
print("BMI:",BMI)
# Out:
# Enter weight in kg:60
# Enter height in meters:1.65
# BMI: 22.03856749311295

# %%
o = int(input("Enter original price:"))
s = 0.10*o
n = o-s
print("Discount price:",n)
# Out:
# Enter original price:1200
# Discount price: 1080.0

# %%
a = int(input("Enter side A of triangle:"))
b = int(input("Enter side B of triangle:"))
c = int(input("Enter side C of triangle:"))
s = (a+b+c)/2
area = (s*(s-a)*(s-b)*(s-c))**0.5
print("Area of triangle:", area)
# Out:
# Enter side A of triangle:5
# Enter side B of triangle:6
# Enter side C of triangle:7
# Area of triangle: 14.696938456699069

# %%
w = int(input("Enter wall length:")
h = int(input("Enter wall height"))
a = 1.5*1.2
p = w*h
pa= p-w
cost = area*25
print(Area of wall:", area")
print(Total painting cost:,cost)
# Out:
#   File "/tmp/ipython-input-2473622902.py", line 1
#     w = int(input("Enter wall length:")
#            ^
# SyntaxError: '(' was never closed

# %%
a = int(input("Enter number of unitss consumed"))
unit =250
bill = (unit*5.2)+100
print("Electricity ")
